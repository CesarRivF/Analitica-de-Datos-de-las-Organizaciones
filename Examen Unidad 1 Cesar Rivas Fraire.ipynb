# %%
import pandas as pd

# %%
games = pd.DataFrame

# %%
games
# Out:
# pandas.core.frame.DataFrame

# %%
games = pd.read_csv("VGSales.csv")

# %%
games
# Out:
#         Rank                    Nombre Plataforma    Year     Genre  \
# 0         90                   Pac-Man       2600  1982.0    Puzzle
# 1        240                  Pitfall!       2600  1981.0  Platform
# 2        259                 Asteroids       2600  1980.0   Shooter
# 3        545           Missile Command       2600  1980.0   Shooter
# 4        608            Space Invaders       2600     NaN   Shooter
# ...      ...                       ...        ...     ...       ...
# 16593  16533  Sébastien Loeb Rally Evo       XOne  2016.0    Racing
# 16594  16534             Hitman (2016)       XOne  2016.0    Action
# 16595  16565              Mighty No. 9       XOne  2016.0  Platform
# 16596  16572        Resident Evil 4 HD       XOne  2016.0   Shooter
# 16597  16579         Rugby Challenge 3       XOne  2016.0    Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                     Atari      7.28      0.45       0.0         0.08
# ...

# %%
juegos = games[games['Rank'] >= 16500]

# %%
juegos
# Out:
#         Rank                                             Nombre Plataforma  \
# 639    16515                                      Balloon Pop 2        3DS
# 640    16531                                  Kiniro no Corda 3        3DS
# 641    16538                                       Mushi Bugyou        3DS
# 642    16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...        3DS
# 643    16570  Fujiko F. Fujio Characters: Great Assembly! Sl...        3DS
# ...      ...                                                ...        ...
# 16593  16533                           Sébastien Loeb Rally Evo       XOne
# 16594  16534                                      Hitman (2016)       XOne
# 16595  16565                                       Mighty No. 9       XOne
# 16596  16572                                 Resident Evil 4 HD       XOne
# 16597  16579                                  Rugby Challenge 3       XOne
#
# ...

# %%
empresa_deseada = "Atari"

# %%
print(empresa_deseada)
# Out:
# Atari

# %%
juegos = games[games['publisher'] ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'publisher'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
juegos = games[(games['Atari'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Atari'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
empresa_deseada = "Atari"
genero_deseado = "Accion"

# %%
juegos_atari_accion = games[(games["Atari"] == empresa_deseada) & (games['Accion'] == genero_deseado)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Atari'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
juegos = games[games['Atari'] < 54]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Atari'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
juegosatari = games[(games["Publisher"]== "Atari") &
                       (games["Genre"]== "Action")]
juegosatari.count()
# Out:
# Rank            54
# Nombre          54
# Plataforma      54
# Year            49
# Genre           54
# Publisher       54
# NA_Sales        54
# EU_Sales        54
# JP_Sales        54
# Other_Sales     54
# Global_Sales    54
# dtype: int64

# %%
juegosfecha = games[(games["Year"] == 1987.0) & (games["Plataforma"] == "NES")]
juegosfecha.count()
# Out:
# Rank            10
# Nombre          10
# Plataforma      10
# Year            10
# Genre           10
# Publisher       10
# NA_Sales        10
# EU_Sales        10
# JP_Sales        10
# Other_Sales     10
# Global_Sales    10
# dtype: int64

# %%
plataformasJuegos = ["PS4", "Wii", "X360"]
generosJuegos = ["Action", "Fighting", "Puzzle"]

plataformas_generos = games[(games["Plataforma"].isin(plataformas)) & (games["Genre"].isin(generos))]
plataformas_generos.count()
# Out:
# Rank            871
# Nombre          871
# Plataforma      871
# Year            854
# Genre           871
# Publisher       870
# NA_Sales        871
# EU_Sales        871
# JP_Sales        871
# Other_Sales     871
# Global_Sales    871
# dtype: int64

# %%
AlSuper = pd.read_csv("supermarket_sales.csv")
AlSuper
# Out:
#        Invoice ID Branch       City Customer type  Gender  \
# 0     253-12-6086      A     Yangon        Member  Female
# 1     276-54-0879      B   Mandalay        Normal    Male
# 2     373-14-0504      A     Yangon        Member  Female
# 3     659-36-1684      C  Naypyitaw        Member    Male
# 4     751-15-6198      B   Mandalay        Normal    Male
# ...           ...    ...        ...           ...     ...
# 1005  811-03-8790      A  Naypyitaw        Normal  Female
# 1006  551-21-3069      C  Naypyitaw        Normal  Female
# 1007  416-17-9926      A  Naypyitaw        Member  Female
# 1008  556-97-7101      C  Naypyitaw        Normal  Female
# 1009  891-01-7034      B  Naypyitaw        Normal  Female
#
#                 Product line  Unit price  Quantity   Tax 5%     Total  Rating  \
# 0          Sports and travel       98.40         7  34.4400   $723.24     8.7
# 1          Sports and travel       97.74         4  19.5480   $410.51     6.4
# ...

# %%
consultaciudad = AlSuper[(AlSuper["City"] == "Yangon") & 
                      (AlSuper["Gender"] == "Male") & 
                      (AlSuper["Product line"] == "Sports and travel") & 
                      (AlSuper["Payment"] == "Credit card")]
consultaciudad.count()
# Out:
# Invoice ID                 9
# Branch                     9
# City                       9
# Customer type              9
# Gender                     9
# Product line               9
# Unit price                 9
# Quantity                   9
# Tax 5%                     9
# Total                      9
# Rating                     9
# Payment                    9
# Date                       9
# Time                       9
# cogs                       9
# gross margin percentage    9
# gross income               9
# dtype: int64

# %%
consultaclientes = AlSuper[(AlSuper["City"] == "Naypyitaw") & 
                   (AlSuper["Customer type"] == "Member") & 
                   ((AlSuper["Payment"] == "Cash") | (AlSuper["Payment"] == "Ewallet"))]
consultaclientes.count()
# Out:
# Invoice ID                 109
# Branch                     109
# City                       109
# Customer type              109
# Gender                     109
# Product line               109
# Unit price                 109
# Quantity                   109
# Tax 5%                     109
# Total                      109
# Rating                     109
# Payment                    109
# Date                       109
# Time                       109
# cogs                       109
# gross margin percentage    109
# gross income               109
# dtype: int64
